# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('df1_cleaned.csv')

# %%
df.head(10)
# Out:
#    Release Year                             Title Origin/Ethnicity  \
# 0          1901            Kansas Saloon Smashers         American
# 1          1901     Love by the Light of the Moon         American
# 2          1901           The Martyred Presidents         American
# 3          1901  Terrible Teddy, the Grizzly King         American
# 4          1902            Jack and the Beanstalk         American
# 5          1903               Alice in Wonderland         American
# 6          1903           The Great Train Robbery         American
# 7          1904                   The Suburbanite         American
# 8          1905          The Little Train Robbery         American
# 9          1905        The Night Before Christmas         American
#
#                              Director       Cast    Genre  \
# 0                                 NaN        NaN      NaN
# 1                                 NaN        NaN      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 34884 entries, 0 to 34883
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Release Year      34884 non-null  int64
#  1   Title             34884 non-null  str
#  2   Origin/Ethnicity  34884 non-null  str
#  3   Director          33752 non-null  str
#  4   Cast              33429 non-null  str
#  5   Genre             28774 non-null  str
#  6   Wiki Page         34884 non-null  str
#  7   Plot              34884 non-null  str
#  8   clean_plot        34883 non-null  str
#  9   cast_list         34884 non-null  str
#  10  genre_list        34884 non-null  str
# dtypes: int64(1), str(10)
# memory usage: 2.9 MB

# %%
# Assuming 'df' is your DataFrame and 'feature_column' is your column name
count = (df['Director'].str.len() <= 2).sum()

print(f"Number of rows with length < 2: {count}")
# Out:
# Number of rows with length < 2: 1

# %%
count = (df['Cast'].str.len() <= 2).sum()

print(f"Number of rows with length < 2: {count}")
# Out:
# Number of rows with length < 2: 0

# %%
count = (df['Genre'].str.len() <=2 ).sum()

print(f"Number of rows with length < 2: {count}")
# Out:
# Number of rows with length < 2: 4

# %%
df["cast_list"].head(5)
# Out:
# 0    []
# 1    []
# 2    []
# 3    []
# 4    []
# Name: cast_list, dtype: str

# %%
df["cast_list"].apply(type).value_counts()
# Out:
# cast_list
# <class 'str'>    34884
# Name: count, dtype: int64

# %%
def normalize_cast(cast):
    if not isinstance(cast, str) or cast.strip() == "":
        return []
    return [c.strip() for c in cast.split(",") if c.strip()]

df["cast_list"] = df["Cast"].apply(normalize_cast)

# %%
df["cast_list"].apply(type).value_counts()
# Out:
# cast_list
# <class 'list'>    34884
# Name: count, dtype: int64
